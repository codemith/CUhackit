# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Load the dataset
file_path = 'Belt 1 Test Data.xlsx'  # Update with your actual file path if needed
all_sheets = pd.read_excel(file_path, header=None, sheet_name=None)

column_names = [
    "Name","Timestamp", "Status", "Description","Vibration Frequency","Vibration Amplitude", "Bearing Temperature", 
    "Motor Temperature", "Belt Load", "Torque", "Noise Levels", "Current and Voltage", 
    "Hydraulic Pressure","Belt Thickness", "Roller Condition" 
    
]
for sheet_name, df in all_sheets.items():
    df.columns = column_names
    
    print("First 5 rows:")
    print(df.head())
    print("\nData Info:")
    print(df.info())
    print("\nSummary Statistics:")
    print(df.describe())

    # Step 3: Check for missing values
    missing = df.isnull().sum()
    print("\nMissing Values per Column:")
    print(missing)

    # Visualize missing values
    missing.plot(kind='bar', title='Missing Values per Column')
    plt.xlabel('Columns')
    plt.ylabel('Number of Missing Values')
    plt.show()

    # Step 2: Quick overview of the data
# Out:
# First 5 rows:
#               Name           Timestamp   Status Description  \
# 0  Conveyor Belt 4 2026-05-14 00:15:00  Running         NaN
# 1  Conveyor Belt 4 2026-05-14 00:30:00  Running         NaN
# 2  Conveyor Belt 4 2026-05-14 00:45:00  Running         NaN
# 3  Conveyor Belt 4 2026-05-14 01:00:00  Running         NaN
# 4  Conveyor Belt 4 2026-05-14 01:15:00  Running         NaN
#
#    Vibration Frequency  Vibration Amplitude  Bearing Temperature  \
# 0              1498.37                 0.04               77.076
# 1              1503.22                 0.06               77.307
# 2              1508.11                 0.04               77.474
# 3              1498.13                 0.06               77.785
# 4              1494.89                 0.05               77.813
#
#    Motor Temperature  Belt Load  Torque  Noise Levels  Current and Voltage  \
# 0             96.975       1.07  295.50         59.68                14.34
# 1             96.755       1.21  314.38         58.20                15.03
# 2             97.661       1.29  311.84         56.16                15.43
# 3             97.471       1.07  317.14         55.39                14.35
# 4             97.814       1.33  305.58         62.25                15.65
#
#    Hydraulic Pressure  Belt Thickness  Roller Condition
# 0              376.48         1.54675            68.245
# 1              384.20         1.54650            68.172
# 2              379.79         1.54625            68.099
# 3              383.95         1.54600            68.026
# 4              383.02         1.54575            67.953
#
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1439 entries, 0 to 1438
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 1439 non-null   object
#  1   Timestamp            1439 non-null   datetime64[ns]
#  2   Status               1439 non-null   object
#  3   Description          105 non-null    object
#  4   Vibration Frequency  1439 non-null   float64
#  5   Vibration Amplitude  1439 non-null   float64
#  6   Bearing Temperature  1439 non-null   float64
#  7   Motor Temperature    1439 non-null   float64
#  8   Belt Load            1439 non-null   float64
#  9   Torque               1439 non-null   float64
#  10  Noise Levels         1439 non-null   float64
#  11  Current and Voltage  1439 non-null   float64
#  12  Hydraulic Pressure   1439 non-null   float64
#  13  Belt Thickness       1439 non-null   float64
#  14  Roller Condition     1439 non-null   float64
# dtypes: datetime64[ns](1), float64(11), object(3)
# memory usage: 168.8+ KB
# None
#
# Summary Statistics:
#        Vibration Frequency  Vibration Amplitude  Bearing Temperature  \
# count          1439.000000          1439.000000          1439.000000
# mean           1499.180751             0.049486            68.991942
# std               5.719487             0.007689             5.827120
# min            1483.620000             0.040000            60.000000
# 25%            1494.400000             0.040000            64.204000
# 50%            1499.180000             0.050000            68.584000
# 75%            1503.540000             0.060000            74.179000
# max            1527.020000             0.060000            78.848000
#
#        Motor Temperature    Belt Load       Torque  Noise Levels  \
# count        1439.000000  1439.000000  1439.000000   1439.000000
# mean           88.635103     1.193947   299.772397     59.926359
# std             5.840259     0.116623    12.511711      3.117412
# min            80.000000     1.000000   280.000000     55.000000
# 25%            83.316000     1.100000   287.595000     57.920000
# 50%            88.478000     1.180000   299.840000     59.740000
# 75%            93.289000     1.290000   311.370000     62.765000
# max            99.410000     1.400000   319.710000     65.000000
#
#        Current and Voltage  Hydraulic Pressure  Belt Thickness  \
# count          1439.000000         1439.000000     1439.000000
# mean             14.967095          379.948930        1.613786
# std               0.622383            3.183695        0.058013
# min              12.810000          375.000000        1.522000
# 25%              14.480000          377.230000        1.557000
# 50%              14.910000          379.920000        1.617000
# 75%              15.470000          383.175000        1.668875
# max              17.980000          384.930000        1.700000
#
#        Roller Condition
# count       1439.000000
# mean          83.971402
# std            9.400259
# min           67.515000
# 25%           75.764000
# 50%           84.013000
# 75%           92.225500
# max          100.000000
#
# Missing Values per Column:
# Name                      0
# Timestamp                 0
# Status                    0
# Description            1334
# Vibration Frequency       0
# Vibration Amplitude       0
# Bearing Temperature       0
# Motor Temperature         0
# Belt Load                 0
# Torque                    0
# Noise Levels              0
# Current and Voltage       0
# Hydraulic Pressure        0
# Belt Thickness            0
# Roller Condition          0
# dtype: int64
# First 5 rows:
#               Name           Timestamp   Status Description  \
# 0  Conveyor Belt 4 2026-05-14 00:15:00  Running         NaN
# 1  Conveyor Belt 4 2026-05-14 00:30:00  Running         NaN
# 2  Conveyor Belt 4 2026-05-14 00:45:00  Running         NaN
# 3  Conveyor Belt 4 2026-05-14 01:00:00  Running         NaN
# 4  Conveyor Belt 4 2026-05-14 01:15:00  Running         NaN
#
#    Vibration Frequency  Vibration Amplitude  Bearing Temperature  \
# 0              1498.37                 0.04               77.076
# 1              1503.22                 0.06               77.307
# 2              1508.11                 0.04               77.474
# 3              1498.13                 0.06               77.785
# 4              1494.89                 0.05               77.813
#
#    Motor Temperature  Belt Load  Torque  Noise Levels  Current and Voltage  \
# 0             96.975       1.07  295.50         59.68                14.34
# 1             96.755       1.21  314.38         58.20                15.03
# 2             97.661       1.29  311.84         56.16                15.43
# 3             97.471       1.07  317.14         55.39                14.35
# 4             97.814       1.33  305.58         62.25                15.65
#
#    Hydraulic Pressure  Belt Thickness  Roller Condition
# 0              376.48         1.54675            68.245
# 1              384.20         1.54650            68.172
# 2              379.79         1.54625            68.099
# 3              383.95         1.54600            68.026
# 4              383.02         1.54575            67.953
#
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 719 entries, 0 to 718
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 719 non-null    object
#  1   Timestamp            719 non-null    datetime64[ns]
#  2   Status               719 non-null    object
#  3   Description          56 non-null     object
#  4   Vibration Frequency  719 non-null    float64
#  5   Vibration Amplitude  719 non-null    float64
#  6   Bearing Temperature  719 non-null    float64
#  7   Motor Temperature    719 non-null    float64
#  8   Belt Load            719 non-null    float64
#  9   Torque               719 non-null    float64
#  10  Noise Levels         719 non-null    float64
#  11  Current and Voltage  719 non-null    float64
#  12  Hydraulic Pressure   719 non-null    float64
#  13  Belt Thickness       719 non-null    float64
#  14  Roller Condition     719 non-null    float64
# dtypes: datetime64[ns](1), float64(11), object(3)
# memory usage: 84.4+ KB
# None
#
# Summary Statistics:
#        Vibration Frequency  Vibration Amplitude  Bearing Temperature  \
# count           719.000000           719.000000           719.000000
# mean           1499.095076             0.050723            68.820750
# std               5.583983             0.010727             5.932306
# min            1490.000000             0.040000            60.000000
# 25%            1494.400000             0.040000            63.926000
# 50%            1499.080000             0.050000            68.576000
# 75%            1503.505000             0.060000            74.179000
# max            1509.660000             0.080000            78.848000
#
#        Motor Temperature   Belt Load      Torque  Noise Levels  \
# count         719.000000  719.000000  719.000000    719.000000
# mean           88.467082    1.192796  299.626231     59.972656
# std             5.951330    0.117520   12.550950      4.492228
# min            80.000000    1.000000  280.000000     47.430000
# 25%            83.116000    1.100000  287.370000     56.580000
# 50%            88.167000    1.180000  299.840000     59.740000
# 75%            93.289000    1.290000  311.370000     62.940000
# max            99.410000    1.400000  319.710000     74.540000
#
#        Current and Voltage  Hydraulic Pressure  Belt Thickness  \
# count           719.000000          719.000000      719.000000
# mean             14.960918          379.944242        1.615695
# std               0.589525            3.198026        0.050775
# min              14.000000          375.000000        1.522000
# 25%              14.480000          377.230000        1.575625
# 50%              14.910000          379.920000        1.617000
# 75%              15.460000          383.190000        1.658375
# max              16.000000          384.930000        1.700000
#
#        Roller Condition
# count        719.000000
# mean          86.425249
# std            9.302148
# min           67.515000
# 25%           79.304500
# 50%           87.882000
# 75%           93.904500
# max          100.000000
#
# Missing Values per Column:
# Name                     0
# Timestamp                0
# Status                   0
# Description            663
# Vibration Frequency      0
# Vibration Amplitude      0
# Bearing Temperature      0
# Motor Temperature        0
# Belt Load                0
# Torque                   0
# Noise Levels             0
# Current and Voltage      0
# Hydraulic Pressure       0
# Belt Thickness           0
# Roller Condition         0
# dtype: int64
# First 5 rows:
#               Name           Timestamp   Status Description  \
# 0  Conveyor Belt 4 2026-05-14 00:15:00  Running         NaN
# 1  Conveyor Belt 4 2026-05-14 00:30:00  Running         NaN
# 2  Conveyor Belt 4 2026-05-14 00:45:00  Running         NaN
# 3  Conveyor Belt 4 2026-05-14 01:00:00  Running         NaN
# 4  Conveyor Belt 4 2026-05-14 01:15:00  Running         NaN
#
#    Vibration Frequency  Vibration Amplitude  Bearing Temperature  \
# 0              1498.37                 0.04               77.076
# 1              1503.22                 0.06               77.307
# 2              1508.11                 0.04               77.474
# 3              1498.13                 0.06               77.785
# 4              1494.89                 0.05               77.813
#
#    Motor Temperature  Belt Load  Torque  Noise Levels  Current and Voltage  \
# 0             96.975       1.07  295.50         59.68                14.34
# 1             96.755       1.21  314.38         58.20                15.03
# 2             97.661       1.29  311.84         56.16                15.43
# 3             97.471       1.07  317.14         55.39                14.35
# 4             97.814       1.33  305.58         62.25                15.65
#
#    Hydraulic Pressure  Belt Thickness  Roller Condition
# 0              376.48         1.54675            68.245
# 1              384.20         1.54650            68.172
# 2              379.79         1.54625            68.099
# 3              383.95         1.54600            68.026
# 4              383.02         1.54575            67.953
#
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2554 entries, 0 to 2553
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 2554 non-null   object
#  1   Timestamp            2554 non-null   datetime64[ns]
#  2   Status               2554 non-null   object
#  3   Description          189 non-null    object
#  4   Vibration Frequency  2554 non-null   float64
#  5   Vibration Amplitude  2554 non-null   float64
#  6   Bearing Temperature  2554 non-null   float64
#  7   Motor Temperature    2554 non-null   float64
#  8   Belt Load            2554 non-null   float64
#  9   Torque               2554 non-null   float64
#  10  Noise Levels         2554 non-null   float64
#  11  Current and Voltage  2554 non-null   float64
#  12  Hydraulic Pressure   2554 non-null   float64
#  13  Belt Thickness       2554 non-null   float64
#  14  Roller Condition     2554 non-null   float64
# dtypes: datetime64[ns](1), float64(11), object(3)
# memory usage: 299.4+ KB
# None
#
# Summary Statistics:
#        Vibration Frequency  Vibration Amplitude  Bearing Temperature  \
# count          2554.000000          2554.000000          2554.000000
# mean           1499.123324             0.049487            68.983648
# std               5.563809             0.007686             6.570904
# min            1490.000000             0.040000            43.750000
# 25%            1494.400000             0.040000            63.926000
# 50%            1499.130000             0.050000            68.584000
# 75%            1503.540000             0.060000            74.330000
# max            1509.660000             0.060000            95.610000
#
#        Motor Temperature    Belt Load       Torque  Noise Levels  \
# count        2554.000000  2554.000000  2554.000000   2554.000000
# mean           88.586271     1.193865   299.740431     59.919832
# std             5.860481     0.116866    12.530536      3.116840
# min            80.000000     1.000000   280.000000     55.000000
# 25%            83.138000     1.100000   287.370000     57.920000
# 50%            88.478000     1.180000   299.840000     59.740000
# 75%            93.289000     1.290000   311.370000     62.740000
# max            99.410000     1.400000   319.710000     65.000000
#
#        Current and Voltage  Hydraulic Pressure  Belt Thickness  \
# count          2554.000000         2554.000000     2554.000000
# mean             14.966237          379.972349        1.616860
# std               0.586241            5.709626        0.053456
# min              14.000000          350.580000        1.522000
# 25%              14.480000          377.000000        1.566750
# 50%              14.910000          379.920000        1.623500
# 75%              15.460000          383.350000        1.663500
# max              16.000000          408.180000        1.700000
#
#        Roller Condition
# count       2554.000000
# mean          84.531860
# std            9.574741
# min           67.515000
# 25%           76.129000
# 50%           84.962000
# 75%           93.211000
# max          100.000000
#
# Missing Values per Column:
# Name                      0
# Timestamp                 0
# Status                    0
# Description            2365
# Vibration Frequency       0
# Vibration Amplitude       0
# Bearing Temperature       0
# Motor Temperature         0
# Belt Load                 0
# Torque                    0
# Noise Levels              0
# Current and Voltage       0
# Hydraulic Pressure        0
# Belt Thickness            0
# Roller Condition          0
# dtype: int64

# %%
for sheet_name, df in all_sheets.items():
    if df['Name'].nunique() == 1:
        print("The 'name' column is constant and will be dropped.")
        df.drop('Name', axis=1, inplace=True)
# Out:
# The 'name' column is constant and will be dropped.
# The 'name' column is constant and will be dropped.
# The 'name' column is constant and will be dropped.

# %%
import pandas as pd

for sheet_name, df in all_sheets.items():
    # Convert 'Timestamp' column to datetime, coercing errors into NaT
    df['Timestamp'] = pd.to_datetime(df['Timestamp'], errors='coerce')

    # Check for any invalid dates that were converted to NaT
    invalid_dates = df[df['Timestamp'].isnull()]
    print("Invalid dates found:\n", invalid_dates)

    # Optionally, drop rows with invalid dates
    df = df.dropna(subset=['Timestamp'])

    # Extract components if needed
    df['year'] = df['Timestamp'].dt.year
    df['month'] = df['Timestamp'].dt.month
    df['day'] = df['Timestamp'].dt.day
    df['hour'] = df['Timestamp'].dt.hour
    df['minute'] = df['Timestamp'].dt.minute
    df['second'] = df['Timestamp'].dt.second

    # Convert to a numeric timestamp if required
    df['timestamp_numeric'] = df['Timestamp'].apply(lambda x: x.timestamp())

    print(df.info())
# Out:
# Invalid dates found:
#  Empty DataFrame
# Columns: [Timestamp, Status, Description, Vibration Frequency, Vibration Amplitude, Bearing Temperature, Motor Temperature, Belt Load, Torque, Noise Levels, Current and Voltage, Hydraulic Pressure, Belt Thickness, Roller Condition]
# Index: []
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1439 entries, 0 to 1438
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Timestamp            1439 non-null   datetime64[ns]
#  1   Status               1439 non-null   object
#  2   Description          105 non-null    object
#  3   Vibration Frequency  1439 non-null   float64
#  4   Vibration Amplitude  1439 non-null   float64
#  5   Bearing Temperature  1439 non-null   float64
#  6   Motor Temperature    1439 non-null   float64
#  7   Belt Load            1439 non-null   float64
#  8   Torque               1439 non-null   float64
#  9   Noise Levels         1439 non-null   float64
#  10  Current and Voltage  1439 non-null   float64
#  11  Hydraulic Pressure   1439 non-null   float64
#  12  Belt Thickness       1439 non-null   float64
#  13  Roller Condition     1439 non-null   float64
#  14  year                 1439 non-null   int64
#  15  month                1439 non-null   int64
#  16  day                  1439 non-null   int64
#  17  hour                 1439 non-null   int64
#  18  minute               1439 non-null   int64
#  19  second               1439 non-null   int64
#  20  timestamp_numeric    1439 non-null   float64
# dtypes: datetime64[ns](1), float64(12), int64(6), object(2)
# memory usage: 247.3+ KB
# None
# Invalid dates found:
#  Empty DataFrame
# Columns: [Timestamp, Status, Description, Vibration Frequency, Vibration Amplitude, Bearing Temperature, Motor Temperature, Belt Load, Torque, Noise Levels, Current and Voltage, Hydraulic Pressure, Belt Thickness, Roller Condition]
# Index: []
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 719 entries, 0 to 718
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Timestamp            719 non-null    datetime64[ns]
#  1   Status               719 non-null    object
#  2   Description          56 non-null     object
#  3   Vibration Frequency  719 non-null    float64
#  4   Vibration Amplitude  719 non-null    float64
#  5   Bearing Temperature  719 non-null    float64
#  6   Motor Temperature    719 non-null    float64
#  7   Belt Load            719 non-null    float64
#  8   Torque               719 non-null    float64
#  9   Noise Levels         719 non-null    float64
#  10  Current and Voltage  719 non-null    float64
#  11  Hydraulic Pressure   719 non-null    float64
#  12  Belt Thickness       719 non-null    float64
#  13  Roller Condition     719 non-null    float64
#  14  year                 719 non-null    int64
#  15  month                719 non-null    int64
#  16  day                  719 non-null    int64
#  17  hour                 719 non-null    int64
#  18  minute               719 non-null    int64
#  19  second               719 non-null    int64
#  20  timestamp_numeric    719 non-null    float64
# dtypes: datetime64[ns](1), float64(12), int64(6), object(2)
# memory usage: 123.6+ KB
# None
# Invalid dates found:
#  Empty DataFrame
# Columns: [Timestamp, Status, Description, Vibration Frequency, Vibration Amplitude, Bearing Temperature, Motor Temperature, Belt Load, Torque, Noise Levels, Current and Voltage, Hydraulic Pressure, Belt Thickness, Roller Condition]
# Index: []
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2554 entries, 0 to 2553
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Timestamp            2554 non-null   datetime64[ns]
#  1   Status               2554 non-null   object
#  2   Description          189 non-null    object
#  3   Vibration Frequency  2554 non-null   float64
#  4   Vibration Amplitude  2554 non-null   float64
#  5   Bearing Temperature  2554 non-null   float64
#  6   Motor Temperature    2554 non-null   float64
#  7   Belt Load            2554 non-null   float64
#  8   Torque               2554 non-null   float64
#  9   Noise Levels         2554 non-null   float64
#  10  Current and Voltage  2554 non-null   float64
#  11  Hydraulic Pressure   2554 non-null   float64
#  12  Belt Thickness       2554 non-null   float64
#  13  Roller Condition     2554 non-null   float64
#  14  year                 2554 non-null   int64
#  15  month                2554 non-null   int64
#  16  day                  2554 non-null   int64
#  17  hour                 2554 non-null   int64
#  18  minute               2554 non-null   int64
#  19  second               2554 non-null   int64
#  20  timestamp_numeric    2554 non-null   float64
# dtypes: datetime64[ns](1), float64(12), int64(6), object(2)
# memory usage: 439.0+ KB
# None

# %%
for sheet_name, df in all_sheets.items():
    nat_count = df['Timestamp'].isna().sum()
    print("Number of NaT values in 'Timestamp':", nat_count)
    df.head()
# Out:
# Number of NaT values in 'Timestamp': 0
# Number of NaT values in 'Timestamp': 0
# Number of NaT values in 'Timestamp': 0

# %%
for sheet_name, df in all_sheets.items():
    # One-Hot Encode the Status column
    df = pd.get_dummies(df, columns=['Status'], prefix='status')
    print(df.head())
# Out:
#             Timestamp Description  Vibration Frequency  Vibration Amplitude  \
# 0 2026-05-14 00:15:00         NaN              1498.37                 0.04
# 1 2026-05-14 00:30:00         NaN              1503.22                 0.06
# 2 2026-05-14 00:45:00         NaN              1508.11                 0.04
# 3 2026-05-14 01:00:00         NaN              1498.13                 0.06
# 4 2026-05-14 01:15:00         NaN              1494.89                 0.05
#
#    Bearing Temperature  Motor Temperature  Belt Load  Torque  Noise Levels  \
# 0               77.076             96.975       1.07  295.50         59.68
# 1               77.307             96.755       1.21  314.38         58.20
# 2               77.474             97.661       1.29  311.84         56.16
# 3               77.785             97.471       1.07  317.14         55.39
# 4               77.813             97.814       1.33  305.58         62.25
#
#    Current and Voltage  Hydraulic Pressure  Belt Thickness  Roller Condition  \
# 0                14.34              376.48         1.54675            68.245
# 1                15.03              384.20         1.54650            68.172
# 2                15.43              379.79         1.54625            68.099
# 3                14.35              383.95         1.54600            68.026
# 4                15.65              383.02         1.54575            67.953
#
#    status_Maintenance  status_Running
# 0                   0               1
# 1                   0               1
# 2                   0               1
# 3                   0               1
# 4                   0               1
#             Timestamp Description  Vibration Frequency  Vibration Amplitude  \
# 0 2026-05-14 00:15:00         NaN              1498.37                 0.04
# 1 2026-05-14 00:30:00         NaN              1503.22                 0.06
# 2 2026-05-14 00:45:00         NaN              1508.11                 0.04
# 3 2026-05-14 01:00:00         NaN              1498.13                 0.06
# 4 2026-05-14 01:15:00         NaN              1494.89                 0.05
#
#    Bearing Temperature  Motor Temperature  Belt Load  Torque  Noise Levels  \
# 0               77.076             96.975       1.07  295.50         59.68
# 1               77.307             96.755       1.21  314.38         58.20
# 2               77.474             97.661       1.29  311.84         56.16
# 3               77.785             97.471       1.07  317.14         55.39
# 4               77.813             97.814       1.33  305.58         62.25
#
#    Current and Voltage  Hydraulic Pressure  Belt Thickness  Roller Condition  \
# 0                14.34              376.48         1.54675            68.245
# 1                15.03              384.20         1.54650            68.172
# 2                15.43              379.79         1.54625            68.099
# 3                14.35              383.95         1.54600            68.026
# 4                15.65              383.02         1.54575            67.953
#
#    status_Maintenance  status_Running
# 0                   0               1
# 1                   0               1
# 2                   0               1
# 3                   0               1
# 4                   0               1
#             Timestamp Description  Vibration Frequency  Vibration Amplitude  \
# 0 2026-05-14 00:15:00         NaN              1498.37                 0.04
# 1 2026-05-14 00:30:00         NaN              1503.22                 0.06
# 2 2026-05-14 00:45:00         NaN              1508.11                 0.04
# 3 2026-05-14 01:00:00         NaN              1498.13                 0.06
# 4 2026-05-14 01:15:00         NaN              1494.89                 0.05
#
#    Bearing Temperature  Motor Temperature  Belt Load  Torque  Noise Levels  \
# 0               77.076             96.975       1.07  295.50         59.68
# 1               77.307             96.755       1.21  314.38         58.20
# 2               77.474             97.661       1.29  311.84         56.16
# 3               77.785             97.471       1.07  317.14         55.39
# 4               77.813             97.814       1.33  305.58         62.25
#
#    Current and Voltage  Hydraulic Pressure  Belt Thickness  Roller Condition  \
# 0                14.34              376.48         1.54675            68.245
# 1                15.03              384.20         1.54650            68.172
# 2                15.43              379.79         1.54625            68.099
# 3                14.35              383.95         1.54600            68.026
# 4                15.65              383.02         1.54575            67.953
#
#    status_Maintenance  status_Running
# 0                   0               1
# 1                   0               1
# 2                   0               1
# 3                   0               1
# 4                   0               1

# %%
mydf=""
for sheet_name, df in all_sheets.items():
    # Identify non-numeric columns
    non_numeric_cols = df.select_dtypes(include=['object']).columns
    print("Non-numeric columns:", non_numeric_cols)

    # Drop non-numeric columns that are not needed for the model
    df_model = df.drop(non_numeric_cols, axis=1)
    df=df_model
    print(df.head())
# Out:
# Non-numeric columns: Index(['Status', 'Description'], dtype='object')
#             Timestamp  Vibration Frequency  Vibration Amplitude  \
# 0 2026-05-14 00:15:00              1498.37                 0.04
# 1 2026-05-14 00:30:00              1503.22                 0.06
# 2 2026-05-14 00:45:00              1508.11                 0.04
# 3 2026-05-14 01:00:00              1498.13                 0.06
# 4 2026-05-14 01:15:00              1494.89                 0.05
#
#    Bearing Temperature  Motor Temperature  Belt Load  Torque  Noise Levels  \
# 0               77.076             96.975       1.07  295.50         59.68
# 1               77.307             96.755       1.21  314.38         58.20
# 2               77.474             97.661       1.29  311.84         56.16
# 3               77.785             97.471       1.07  317.14         55.39
# 4               77.813             97.814       1.33  305.58         62.25
#
#    Current and Voltage  Hydraulic Pressure  Belt Thickness  Roller Condition
# 0                14.34              376.48         1.54675            68.245
# 1                15.03              384.20         1.54650            68.172
# 2                15.43              379.79         1.54625            68.099
# 3                14.35              383.95         1.54600            68.026
# 4                15.65              383.02         1.54575            67.953
# Non-numeric columns: Index(['Status', 'Description'], dtype='object')
#             Timestamp  Vibration Frequency  Vibration Amplitude  \
# 0 2026-05-14 00:15:00              1498.37                 0.04
# 1 2026-05-14 00:30:00              1503.22                 0.06
# 2 2026-05-14 00:45:00              1508.11                 0.04
# 3 2026-05-14 01:00:00              1498.13                 0.06
# 4 2026-05-14 01:15:00              1494.89                 0.05
#
#    Bearing Temperature  Motor Temperature  Belt Load  Torque  Noise Levels  \
# 0               77.076             96.975       1.07  295.50         59.68
# 1               77.307             96.755       1.21  314.38         58.20
# 2               77.474             97.661       1.29  311.84         56.16
# 3               77.785             97.471       1.07  317.14         55.39
# 4               77.813             97.814       1.33  305.58         62.25
#
#    Current and Voltage  Hydraulic Pressure  Belt Thickness  Roller Condition
# 0                14.34              376.48         1.54675            68.245
# 1                15.03              384.20         1.54650            68.172
# 2                15.43              379.79         1.54625            68.099
# 3                14.35              383.95         1.54600            68.026
# 4                15.65              383.02         1.54575            67.953
# Non-numeric columns: Index(['Status', 'Description'], dtype='object')
#             Timestamp  Vibration Frequency  Vibration Amplitude  \
# 0 2026-05-14 00:15:00              1498.37                 0.04
# 1 2026-05-14 00:30:00              1503.22                 0.06
# 2 2026-05-14 00:45:00              1508.11                 0.04
# 3 2026-05-14 01:00:00              1498.13                 0.06
# 4 2026-05-14 01:15:00              1494.89                 0.05
#
#    Bearing Temperature  Motor Temperature  Belt Load  Torque  Noise Levels  \
# 0               77.076             96.975       1.07  295.50         59.68
# 1               77.307             96.755       1.21  314.38         58.20
# 2               77.474             97.661       1.29  311.84         56.16
# 3               77.785             97.471       1.07  317.14         55.39
# 4               77.813             97.814       1.33  305.58         62.25
#
#    Current and Voltage  Hydraulic Pressure  Belt Thickness  Roller Condition
# 0                14.34              376.48         1.54675            68.245
# 1                15.03              384.20         1.54650            68.172
# 2                15.43              379.79         1.54625            68.099
# 3                14.35              383.95         1.54600            68.026
# 4                15.65              383.02         1.54575            67.953

# %%
import joblib
import pandas as pd
import matplotlib.pyplot as plt

# Load the saved XGBoost models:
clf_model = joblib.load('../xgb_classifier.pkl')   # Classifier for downtime status
reg_model = joblib.load('../xgb_regressor_time_to_event.pkl')  # Time-to-event regressor (predicts offset in seconds)

# Get the expected feature names (they must match what was used during training)
expected_features_clf = clf_model.feature_names_in_
expected_features_reg = reg_model.feature_names_in_

# Assume all_sheets is a dictionary of sheet_name: DataFrame,
# for example:
# all_sheets = pd.read_excel("TestFile.xlsx", sheet_name=None)

final_predictions = []

for sheet_name, df in all_sheets.items():
    # Convert 'Timestamp' to datetime and drop rows with invalid dates
    df['Timestamp'] = pd.to_datetime(df['Timestamp'], errors='coerce')
    df = df.dropna(subset=['Timestamp'])
    
    # Create 'timestamp_numeric' if missing (not strictly needed for time-to-event but kept for consistency)
    if 'timestamp_numeric' not in df.columns:
        df['timestamp_numeric'] = df['Timestamp'].apply(lambda x: x.timestamp())
    
    # Prepare classifier input: reindex DataFrame to match training features and fill missing values with 0
    X_test_clf = df.reindex(columns=expected_features_clf, fill_value=0).fillna(0)
    
    # Get predicted probabilities for downtime (class 1)
    downtime_probs = clf_model.predict_proba(X_test_clf)[:, 1]
    
    # Attach the predicted probabilities to the DataFrame
    df['downtime_prob'] = downtime_probs
    
    # For debugging/inspection, print probability stats and show a histogram
    print(f"\n=== {sheet_name} Probability Stats ===")
    print(f"Min: {df['downtime_prob'].min()}, Max: {df['downtime_prob'].max()}, Mean: {df['downtime_prob'].mean()}")
    plt.hist(df['downtime_prob'], bins=20)
    plt.title(f'Downtime Probability Distribution - {sheet_name}')
    plt.xlabel('Probability')
    plt.ylabel('Count')
    plt.show()
    
    # Sort rows by downtime probability in descending order
    df_sorted = df.sort_values(by='downtime_prob', ascending=False)
    
    # Pick the top candidate row (the one with the highest downtime probability)
    if not df_sorted.empty:
        top_candidate = df_sorted.iloc[0:1].copy()  # a one-row DataFrame
    else:
        top_candidate = pd.DataFrame()
    
    # If no candidate is found, prepare a placeholder
    if top_candidate.empty:
        sheet_predictions = pd.DataFrame({
            'Sheet': [sheet_name],
            'Index': [None],
            'Downtime_Probability': [None],
            'Predicted_Downtime': ["No downtime predicted"]
        })
    else:
        # Prepare regressor input for the top candidate using its expected features
        X_test_reg = top_candidate.reindex(columns=expected_features_reg, fill_value=0).fillna(0)
        # Predict the time-to-downtime offset (in seconds)
        time_offset = reg_model.predict(X_test_reg)[0]
        # Get the current Timestamp of the candidate row
        current_time = top_candidate['Timestamp'].iloc[0]
        # Compute the predicted downtime by adding the offset (converted to a timedelta) to the current Timestamp
        predicted_downtime = current_time + pd.to_timedelta(time_offset, unit='s')
        
        sheet_predictions = pd.DataFrame({
            'Sheet': [sheet_name],
            'Index': top_candidate.index,
            'Downtime_Probability': top_candidate['downtime_prob'],
            'Predicted_Downtime': [predicted_downtime]
        })
    
    final_predictions.append(sheet_predictions)

# Combine predictions from all sheets
if final_predictions:
    final_df = pd.concat(final_predictions, ignore_index=True)
    # Print the output in the requested format for each scenario
    for sheet in final_df['Sheet'].unique():
        row = final_df[final_df['Sheet'] == sheet].iloc[0]
        print(f"Most probable downtime for {sheet} : {row['Predicted_Downtime']}")
    final_df.to_csv('Ranked_Downtime_TimeToEvent.csv', index=False)
else:
    print("No predictions across any sheets.")
# Out:
# === Scenario 1 Probability Stats ===
# Min: 4.860378766124995e-10, Max: 0.16239628195762634, Mean: 0.00011421531962696463
# === Scenario 2 Probability Stats ===
# Min: 8.76530903415329e-10, Max: 0.23330187797546387, Mean: 0.00032870229915715754
# === Scenario 3 Probability Stats ===
# Min: 8.630831604961031e-10, Max: 0.00013401967589743435, Mean: 1.785054337233305e-06
# Most probable downtime for Scenario 1 : 2026-05-26 21:45:00
# Most probable downtime for Scenario 2 : 2026-05-15 11:15:00
# Most probable downtime for Scenario 3 : 2026-06-08 23:30:00
