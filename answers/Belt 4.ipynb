# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Load the dataset
file_path = 'Belt 4 Test Data.xlsx'  # Update with your actual file path if needed
all_sheets = pd.read_excel(file_path, header=None, sheet_name=None)

column_names = [
    "Name","Timestamp", "Status", "Description","Vibration Frequency","Vibration Amplitude", "Bearing Temperature", 
    "Motor Temperature", "Belt Load", "Torque", "Noise Levels", "Current and Voltage", 
    "Hydraulic Pressure","Belt Thickness", "Roller Condition" 
    
]
for sheet_name, df in all_sheets.items():
    df.columns = column_names
    
    print("First 5 rows:")
    print(df.head())
    print("\nData Info:")
    print(df.info())
    print("\nSummary Statistics:")
    print(df.describe())

    # Step 3: Check for missing values
    missing = df.isnull().sum()
    print("\nMissing Values per Column:")
    print(missing)

    # Visualize missing values
    missing.plot(kind='bar', title='Missing Values per Column')
    plt.xlabel('Columns')
    plt.ylabel('Number of Missing Values')
    plt.show()

    # Step 2: Quick overview of the data
# Out:
# First 5 rows:
#               Name           Timestamp   Status Description  \
# 0  Conveyor Belt 4 2026-05-14 00:15:00  Running         NaN
# 1  Conveyor Belt 4 2026-05-14 00:30:00  Running         NaN
# 2  Conveyor Belt 4 2026-05-14 00:45:00  Running         NaN
# 3  Conveyor Belt 4 2026-05-14 01:00:00  Running         NaN
# 4  Conveyor Belt 4 2026-05-14 01:15:00  Running         NaN
#
#    Vibration Frequency  Vibration Amplitude  Bearing Temperature  \
# 0              1498.37                 0.04               77.076
# 1              1503.22                 0.06               77.307
# 2              1508.11                 0.04               77.474
# 3              1498.13                 0.06               77.785
# 4              1494.89                 0.05               77.813
#
#    Motor Temperature  Belt Load  Torque  Noise Levels  Current and Voltage  \
# 0             96.975       1.07  295.50         59.68                14.34
# 1             96.755       1.21  314.38         58.20                15.03
# 2             97.661       1.29  311.84         56.16                15.43
# 3             97.471       1.07  317.14         55.39                14.35
# 4             97.814       1.33  305.58         62.25                15.65
#
#    Hydraulic Pressure  Belt Thickness  Roller Condition
# 0              376.48         1.54675            68.245
# 1              384.20         1.54650            68.172
# 2              379.79         1.54625            68.099
# 3              383.95         1.54600            68.026
# 4              383.02         1.54575            67.953
#
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2313 entries, 0 to 2312
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 2313 non-null   object
#  1   Timestamp            2313 non-null   datetime64[ns]
#  2   Status               2313 non-null   object
#  3   Description          168 non-null    object
#  4   Vibration Frequency  2313 non-null   float64
#  5   Vibration Amplitude  2313 non-null   float64
#  6   Bearing Temperature  2313 non-null   float64
#  7   Motor Temperature    2313 non-null   float64
#  8   Belt Load            2313 non-null   float64
#  9   Torque               2313 non-null   float64
#  10  Noise Levels         2313 non-null   float64
#  11  Current and Voltage  2313 non-null   float64
#  12  Hydraulic Pressure   2313 non-null   float64
#  13  Belt Thickness       2313 non-null   float64
#  14  Roller Condition     2313 non-null   float64
# dtypes: datetime64[ns](1), float64(11), object(3)
# memory usage: 271.2+ KB
# None
#
# Summary Statistics:
#        Vibration Frequency  Vibration Amplitude  Bearing Temperature  \
# count          2313.000000          2313.000000          2313.000000
# mean           1499.135819             0.049494            69.031939
# std               5.555100             0.007695             5.842919
# min            1490.000000             0.040000            60.000000
# 25%            1494.410000             0.040000            64.396000
# 50%            1499.180000             0.050000            68.816000
# 75%            1503.540000             0.060000            74.230000
# max            1509.660000             0.060000            78.848000
#
#        Motor Temperature    Belt Load       Torque  Noise Levels  \
# count        2313.000000  2313.000000  2313.000000   2313.000000
# mean           88.716387     1.194012   299.772196     59.920666
# std             7.224404     0.116565    13.460004      3.116121
# min            56.370000     1.000000   249.980000     55.000000
# 25%            83.116000     1.100000   287.370000     57.920000
# 50%            88.517000     1.180000   299.840000     59.680000
# 75%            93.580000     1.290000   311.460000     62.740000
# max           122.650000     1.400000   347.750000     65.000000
#
#        Current and Voltage  Hydraulic Pressure  Belt Thickness  \
# count          2313.000000         2313.000000     2313.000000
# mean             14.966948          379.951950        1.615616
# std               0.584712            3.182484        0.055784
# min              14.000000          375.000000        1.522000
# 25%              14.480000          377.280000        1.563000
# 50%              14.910000          379.920000        1.620500
# 75%              15.460000          383.190000        1.667250
# max              16.000000          384.930000        1.700000
#
#        Roller Condition
# count       2313.000000
# mean          84.431937
# std            9.247923
# min           67.515000
# 25%           76.713000
# 50%           84.597000
# 75%           92.554000
# max          100.000000
#
# Missing Values per Column:
# Name                      0
# Timestamp                 0
# Status                    0
# Description            2145
# Vibration Frequency       0
# Vibration Amplitude       0
# Bearing Temperature       0
# Motor Temperature         0
# Belt Load                 0
# Torque                    0
# Noise Levels              0
# Current and Voltage       0
# Hydraulic Pressure        0
# Belt Thickness            0
# Roller Condition          0
# dtype: int64
# First 5 rows:
#               Name           Timestamp   Status Description  \
# 0  Conveyor Belt 4 2026-05-14 00:15:00  Running         NaN
# 1  Conveyor Belt 4 2026-05-14 00:30:00  Running         NaN
# 2  Conveyor Belt 4 2026-05-14 00:45:00  Running         NaN
# 3  Conveyor Belt 4 2026-05-14 01:00:00  Running         NaN
# 4  Conveyor Belt 4 2026-05-14 01:15:00  Running         NaN
#
#    Vibration Frequency  Vibration Amplitude  Bearing Temperature  \
# 0              1498.37                 0.04               77.076
# 1              1503.22                 0.06               77.307
# 2              1508.11                 0.04               77.474
# 3              1498.13                 0.06               77.785
# 4              1494.89                 0.05               77.813
#
#    Motor Temperature  Belt Load  Torque  Noise Levels  Current and Voltage  \
# 0             96.975       1.07  295.50         59.68                14.34
# 1             96.755       1.21  314.38         58.20                15.03
# 2             97.661       1.29  311.84         56.16                15.43
# 3             97.471       1.07  317.14         55.39                14.35
# 4             97.814       1.33  305.58         62.25                15.65
#
#    Hydraulic Pressure  Belt Thickness  Roller Condition
# 0              376.48         1.54675            68.245
# 1              384.20         1.54650            68.172
# 2              379.79         1.54625            68.099
# 3              383.95         1.54600            68.026
# 4              383.02         1.54575            67.953
#
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1062 entries, 0 to 1061
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 1062 non-null   object
#  1   Timestamp            1062 non-null   datetime64[ns]
#  2   Status               1062 non-null   object
#  3   Description          77 non-null     object
#  4   Vibration Frequency  1062 non-null   float64
#  5   Vibration Amplitude  1062 non-null   float64
#  6   Bearing Temperature  1062 non-null   float64
#  7   Motor Temperature    1062 non-null   float64
#  8   Belt Load            1062 non-null   float64
#  9   Torque               1062 non-null   float64
#  10  Noise Levels         1062 non-null   float64
#  11  Current and Voltage  1062 non-null   float64
#  12  Hydraulic Pressure   1062 non-null   float64
#  13  Belt Thickness       1062 non-null   float64
#  14  Roller Condition     1062 non-null   float64
# dtypes: datetime64[ns](1), float64(11), object(3)
# memory usage: 124.6+ KB
# None
#
# Summary Statistics:
#        Vibration Frequency  Vibration Amplitude  Bearing Temperature  \
# count          1062.000000          1062.000000          1062.000000
# mean           1499.265518             0.049492            69.246381
# std              10.929895             0.007701             7.679437
# min            1464.290000             0.040000            47.300000
# 25%            1492.730000             0.040000            63.270000
# 50%            1499.160000             0.050000            68.770000
# 75%            1505.202500             0.060000            75.090000
# max            1532.640000             0.060000            93.930000
#
#        Motor Temperature    Belt Load       Torque  Noise Levels  \
# count        1062.000000  1062.000000  1062.000000   1062.000000
# mean           88.690086     1.194049   299.814944     59.914915
# std             5.863095     0.116587    12.516783      3.117052
# min            80.000000     1.000000   280.000000     55.000000
# 25%            83.494000     1.100000   287.820000     57.837500
# 50%            88.517000     1.185000   301.360000     59.680000
# 75%            93.487000     1.290000   311.460000     62.740000
# max            99.410000     1.400000   319.710000     65.000000
#
#        Current and Voltage  Hydraulic Pressure  Belt Thickness  \
# count          1062.000000         1062.000000     1062.000000
# mean             14.967100          379.961036        1.615829
# std               0.584822            3.184602        0.057658
# min              14.000000          375.000000        1.522000
# 25%              14.482500          377.280000        1.559812
# 50%              14.940000          379.930000        1.620875
# 75%              15.460000          383.190000        1.670187
# max              16.000000          384.930000        1.700000
#
#        Roller Condition
# count       1062.000000
# mean          84.922957
# std            9.846116
# min           67.515000
# 25%           76.275000
# 50%           85.436500
# 75%           94.014000
# max          100.000000
#
# Missing Values per Column:
# Name                     0
# Timestamp                0
# Status                   0
# Description            985
# Vibration Frequency      0
# Vibration Amplitude      0
# Bearing Temperature      0
# Motor Temperature        0
# Belt Load                0
# Torque                   0
# Noise Levels             0
# Current and Voltage      0
# Hydraulic Pressure       0
# Belt Thickness           0
# Roller Condition         0
# dtype: int64
# First 5 rows:
#               Name           Timestamp   Status Description  \
# 0  Conveyor Belt 4 2026-05-14 00:15:00  Running         NaN
# 1  Conveyor Belt 4 2026-05-14 00:30:00  Running         NaN
# 2  Conveyor Belt 4 2026-05-14 00:45:00  Running         NaN
# 3  Conveyor Belt 4 2026-05-14 01:00:00  Running         NaN
# 4  Conveyor Belt 4 2026-05-14 01:15:00  Running         NaN
#
#    Vibration Frequency  Vibration Amplitude  Bearing Temperature  \
# 0              1498.37                 0.04               77.076
# 1              1503.22                 0.06               77.307
# 2              1508.11                 0.04               77.474
# 3              1498.13                 0.06               77.785
# 4              1494.89                 0.05               77.813
#
#    Motor Temperature  Belt Load  Torque  Noise Levels  Current and Voltage  \
# 0             96.975       1.07  295.50         59.68                14.34
# 1             96.755       1.21  314.38         58.20                15.03
# 2             97.661       1.29  311.84         56.16                15.43
# 3             97.471       1.07  317.14         55.39                14.35
# 4             97.814       1.33  305.58         62.25                15.65
#
#    Hydraulic Pressure  Belt Thickness  Roller Condition
# 0              376.48         1.54675            68.245
# 1              384.20         1.54650            68.172
# 2              379.79         1.54625            68.099
# 3              383.95         1.54600            68.026
# 4              383.02         1.54575            67.953
#
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1284 entries, 0 to 1283
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 1284 non-null   object
#  1   Timestamp            1284 non-null   datetime64[ns]
#  2   Status               1284 non-null   object
#  3   Description          98 non-null     object
#  4   Vibration Frequency  1284 non-null   float64
#  5   Vibration Amplitude  1284 non-null   float64
#  6   Bearing Temperature  1284 non-null   float64
#  7   Motor Temperature    1284 non-null   float64
#  8   Belt Load            1284 non-null   float64
#  9   Torque               1284 non-null   float64
#  10  Noise Levels         1284 non-null   float64
#  11  Current and Voltage  1284 non-null   float64
#  12  Hydraulic Pressure   1284 non-null   float64
#  13  Belt Thickness       1284 non-null   float64
#  14  Roller Condition     1284 non-null   float64
# dtypes: datetime64[ns](1), float64(11), object(3)
# memory usage: 150.6+ KB
# None
#
# Summary Statistics:
#        Vibration Frequency  Vibration Amplitude  Bearing Temperature  \
# count          1284.000000          1284.000000          1284.000000
# mean           1499.094377             0.049463            68.930474
# std               5.576429             0.007693             5.901558
# min            1490.000000             0.040000            60.000000
# 25%            1494.400000             0.040000            63.926000
# 50%            1499.080000             0.050000            68.584000
# 75%            1503.470000             0.060000            74.230000
# max            1509.660000             0.060000            78.848000
#
#        Motor Temperature    Belt Load       Torque  Noise Levels  \
# count        1284.000000  1284.000000  1284.000000   1284.000000
# mean           88.575909     1.193310   299.714883     59.905678
# std             5.917742     0.116943    12.559014      3.126222
# min            80.000000     1.000000   280.000000     55.000000
# 25%            83.116000     1.100000   287.370000     57.810000
# 50%            88.478000     1.180000   299.840000     59.680000
# 75%            93.487000     1.290000   311.392500     62.740000
# max            99.410000     1.400000   319.710000     65.000000
#
#        Current and Voltage  Hydraulic Pressure  Belt Thickness  \
# count          1284.000000         1284.000000     1284.000000
# mean             14.963450          379.936807        1.612741
# std               0.586555            3.191059        0.055544
# min              14.000000          375.000000        1.522000
# 25%              14.480000          377.180000        1.561000
# 50%              14.910000          379.920000        1.615375
# 75%              15.460000          383.167500        1.663250
# max              16.000000          384.930000        1.700000
#
#        Roller Condition
# count       1284.000000
# mean          85.203116
# std            9.155446
# min           67.515000
# 25%           78.300750
# 50%           85.874500
# 75%           93.156250
# max          100.000000
#
# Missing Values per Column:
# Name                      0
# Timestamp                 0
# Status                    0
# Description            1186
# Vibration Frequency       0
# Vibration Amplitude       0
# Bearing Temperature       0
# Motor Temperature         0
# Belt Load                 0
# Torque                    0
# Noise Levels              0
# Current and Voltage       0
# Hydraulic Pressure        0
# Belt Thickness            0
# Roller Condition          0
# dtype: int64

# %%
for sheet_name, df in all_sheets.items():
    if df['Name'].nunique() == 1:
        print("The 'name' column is constant and will be dropped.")
        df.drop('Name', axis=1, inplace=True)
# Out:
# The 'name' column is constant and will be dropped.
# The 'name' column is constant and will be dropped.
# The 'name' column is constant and will be dropped.

# %%
import pandas as pd

for sheet_name, df in all_sheets.items():
    # Convert 'Timestamp' column to datetime, coercing errors into NaT
    df['Timestamp'] = pd.to_datetime(df['Timestamp'], errors='coerce')

    # Check for any invalid dates that were converted to NaT
    invalid_dates = df[df['Timestamp'].isnull()]
    print("Invalid dates found:\n", invalid_dates)

    # Optionally, drop rows with invalid dates
    df = df.dropna(subset=['Timestamp'])

    # Extract components if needed
    df['year'] = df['Timestamp'].dt.year
    df['month'] = df['Timestamp'].dt.month
    df['day'] = df['Timestamp'].dt.day
    df['hour'] = df['Timestamp'].dt.hour
    df['minute'] = df['Timestamp'].dt.minute
    df['second'] = df['Timestamp'].dt.second

    # Convert to a numeric timestamp if required
    df['timestamp_numeric'] = df['Timestamp'].apply(lambda x: x.timestamp())

    print(df.info())
# Out:
# Invalid dates found:
#  Empty DataFrame
# Columns: [Timestamp, Status, Description, Vibration Frequency, Vibration Amplitude, Bearing Temperature, Motor Temperature, Belt Load, Torque, Noise Levels, Current and Voltage, Hydraulic Pressure, Belt Thickness, Roller Condition]
# Index: []
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2313 entries, 0 to 2312
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Timestamp            2313 non-null   datetime64[ns]
#  1   Status               2313 non-null   object
#  2   Description          168 non-null    object
#  3   Vibration Frequency  2313 non-null   float64
#  4   Vibration Amplitude  2313 non-null   float64
#  5   Bearing Temperature  2313 non-null   float64
#  6   Motor Temperature    2313 non-null   float64
#  7   Belt Load            2313 non-null   float64
#  8   Torque               2313 non-null   float64
#  9   Noise Levels         2313 non-null   float64
#  10  Current and Voltage  2313 non-null   float64
#  11  Hydraulic Pressure   2313 non-null   float64
#  12  Belt Thickness       2313 non-null   float64
#  13  Roller Condition     2313 non-null   float64
#  14  year                 2313 non-null   int64
#  15  month                2313 non-null   int64
#  16  day                  2313 non-null   int64
#  17  hour                 2313 non-null   int64
#  18  minute               2313 non-null   int64
#  19  second               2313 non-null   int64
#  20  timestamp_numeric    2313 non-null   float64
# dtypes: datetime64[ns](1), float64(12), int64(6), object(2)
# memory usage: 397.5+ KB
# None
# Invalid dates found:
#  Empty DataFrame
# Columns: [Timestamp, Status, Description, Vibration Frequency, Vibration Amplitude, Bearing Temperature, Motor Temperature, Belt Load, Torque, Noise Levels, Current and Voltage, Hydraulic Pressure, Belt Thickness, Roller Condition]
# Index: []
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1062 entries, 0 to 1061
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Timestamp            1062 non-null   datetime64[ns]
#  1   Status               1062 non-null   object
#  2   Description          77 non-null     object
#  3   Vibration Frequency  1062 non-null   float64
#  4   Vibration Amplitude  1062 non-null   float64
#  5   Bearing Temperature  1062 non-null   float64
#  6   Motor Temperature    1062 non-null   float64
#  7   Belt Load            1062 non-null   float64
#  8   Torque               1062 non-null   float64
#  9   Noise Levels         1062 non-null   float64
#  10  Current and Voltage  1062 non-null   float64
#  11  Hydraulic Pressure   1062 non-null   float64
#  12  Belt Thickness       1062 non-null   float64
#  13  Roller Condition     1062 non-null   float64
#  14  year                 1062 non-null   int64
#  15  month                1062 non-null   int64
#  16  day                  1062 non-null   int64
#  17  hour                 1062 non-null   int64
#  18  minute               1062 non-null   int64
#  19  second               1062 non-null   int64
#  20  timestamp_numeric    1062 non-null   float64
# dtypes: datetime64[ns](1), float64(12), int64(6), object(2)
# memory usage: 182.5+ KB
# None
# Invalid dates found:
#  Empty DataFrame
# Columns: [Timestamp, Status, Description, Vibration Frequency, Vibration Amplitude, Bearing Temperature, Motor Temperature, Belt Load, Torque, Noise Levels, Current and Voltage, Hydraulic Pressure, Belt Thickness, Roller Condition]
# Index: []
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1284 entries, 0 to 1283
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Timestamp            1284 non-null   datetime64[ns]
#  1   Status               1284 non-null   object
#  2   Description          98 non-null     object
#  3   Vibration Frequency  1284 non-null   float64
#  4   Vibration Amplitude  1284 non-null   float64
#  5   Bearing Temperature  1284 non-null   float64
#  6   Motor Temperature    1284 non-null   float64
#  7   Belt Load            1284 non-null   float64
#  8   Torque               1284 non-null   float64
#  9   Noise Levels         1284 non-null   float64
#  10  Current and Voltage  1284 non-null   float64
#  11  Hydraulic Pressure   1284 non-null   float64
#  12  Belt Thickness       1284 non-null   float64
#  13  Roller Condition     1284 non-null   float64
#  14  year                 1284 non-null   int64
#  15  month                1284 non-null   int64
#  16  day                  1284 non-null   int64
#  17  hour                 1284 non-null   int64
#  18  minute               1284 non-null   int64
#  19  second               1284 non-null   int64
#  20  timestamp_numeric    1284 non-null   float64
# dtypes: datetime64[ns](1), float64(12), int64(6), object(2)
# memory usage: 220.7+ KB
# None

# %%
for sheet_name, df in all_sheets.items():
    nat_count = df['Timestamp'].isna().sum()
    print("Number of NaT values in 'Timestamp':", nat_count)
    df.head()
# Out:
# Number of NaT values in 'Timestamp': 0
# Number of NaT values in 'Timestamp': 0
# Number of NaT values in 'Timestamp': 0

# %%
for sheet_name, df in all_sheets.items():
    # One-Hot Encode the Status column
    df = pd.get_dummies(df, columns=['Status'], prefix='status')
    print(df.head())
# Out:
#             Timestamp Description  Vibration Frequency  Vibration Amplitude  \
# 0 2026-05-14 00:15:00         NaN              1498.37                 0.04
# 1 2026-05-14 00:30:00         NaN              1503.22                 0.06
# 2 2026-05-14 00:45:00         NaN              1508.11                 0.04
# 3 2026-05-14 01:00:00         NaN              1498.13                 0.06
# 4 2026-05-14 01:15:00         NaN              1494.89                 0.05
#
#    Bearing Temperature  Motor Temperature  Belt Load  Torque  Noise Levels  \
# 0               77.076             96.975       1.07  295.50         59.68
# 1               77.307             96.755       1.21  314.38         58.20
# 2               77.474             97.661       1.29  311.84         56.16
# 3               77.785             97.471       1.07  317.14         55.39
# 4               77.813             97.814       1.33  305.58         62.25
#
#    Current and Voltage  Hydraulic Pressure  Belt Thickness  Roller Condition  \
# 0                14.34              376.48         1.54675            68.245
# 1                15.03              384.20         1.54650            68.172
# 2                15.43              379.79         1.54625            68.099
# 3                14.35              383.95         1.54600            68.026
# 4                15.65              383.02         1.54575            67.953
#
#    status_Maintenance  status_Running
# 0                   0               1
# 1                   0               1
# 2                   0               1
# 3                   0               1
# 4                   0               1
#             Timestamp Description  Vibration Frequency  Vibration Amplitude  \
# 0 2026-05-14 00:15:00         NaN              1498.37                 0.04
# 1 2026-05-14 00:30:00         NaN              1503.22                 0.06
# 2 2026-05-14 00:45:00         NaN              1508.11                 0.04
# 3 2026-05-14 01:00:00         NaN              1498.13                 0.06
# 4 2026-05-14 01:15:00         NaN              1494.89                 0.05
#
#    Bearing Temperature  Motor Temperature  Belt Load  Torque  Noise Levels  \
# 0               77.076             96.975       1.07  295.50         59.68
# 1               77.307             96.755       1.21  314.38         58.20
# 2               77.474             97.661       1.29  311.84         56.16
# 3               77.785             97.471       1.07  317.14         55.39
# 4               77.813             97.814       1.33  305.58         62.25
#
#    Current and Voltage  Hydraulic Pressure  Belt Thickness  Roller Condition  \
# 0                14.34              376.48         1.54675            68.245
# 1                15.03              384.20         1.54650            68.172
# 2                15.43              379.79         1.54625            68.099
# 3                14.35              383.95         1.54600            68.026
# 4                15.65              383.02         1.54575            67.953
#
#    status_Maintenance  status_Running
# 0                   0               1
# 1                   0               1
# 2                   0               1
# 3                   0               1
# 4                   0               1
#             Timestamp Description  Vibration Frequency  Vibration Amplitude  \
# 0 2026-05-14 00:15:00         NaN              1498.37                 0.04
# 1 2026-05-14 00:30:00         NaN              1503.22                 0.06
# 2 2026-05-14 00:45:00         NaN              1508.11                 0.04
# 3 2026-05-14 01:00:00         NaN              1498.13                 0.06
# 4 2026-05-14 01:15:00         NaN              1494.89                 0.05
#
#    Bearing Temperature  Motor Temperature  Belt Load  Torque  Noise Levels  \
# 0               77.076             96.975       1.07  295.50         59.68
# 1               77.307             96.755       1.21  314.38         58.20
# 2               77.474             97.661       1.29  311.84         56.16
# 3               77.785             97.471       1.07  317.14         55.39
# 4               77.813             97.814       1.33  305.58         62.25
#
#    Current and Voltage  Hydraulic Pressure  Belt Thickness  Roller Condition  \
# 0                14.34              376.48         1.54675            68.245
# 1                15.03              384.20         1.54650            68.172
# 2                15.43              379.79         1.54625            68.099
# 3                14.35              383.95         1.54600            68.026
# 4                15.65              383.02         1.54575            67.953
#
#    status_Maintenance  status_Running
# 0                   0               1
# 1                   0               1
# 2                   0               1
# 3                   0               1
# 4                   0               1

# %%
mydf=""
for sheet_name, df in all_sheets.items():
    # Identify non-numeric columns
    non_numeric_cols = df.select_dtypes(include=['object']).columns
    print("Non-numeric columns:", non_numeric_cols)

    # Drop non-numeric columns that are not needed for the model
    df_model = df.drop(non_numeric_cols, axis=1)
    df=df_model
    print(df.head())
# Out:
# Non-numeric columns: Index(['Status', 'Description'], dtype='object')
#             Timestamp  Vibration Frequency  Vibration Amplitude  \
# 0 2026-05-14 00:15:00              1498.37                 0.04
# 1 2026-05-14 00:30:00              1503.22                 0.06
# 2 2026-05-14 00:45:00              1508.11                 0.04
# 3 2026-05-14 01:00:00              1498.13                 0.06
# 4 2026-05-14 01:15:00              1494.89                 0.05
#
#    Bearing Temperature  Motor Temperature  Belt Load  Torque  Noise Levels  \
# 0               77.076             96.975       1.07  295.50         59.68
# 1               77.307             96.755       1.21  314.38         58.20
# 2               77.474             97.661       1.29  311.84         56.16
# 3               77.785             97.471       1.07  317.14         55.39
# 4               77.813             97.814       1.33  305.58         62.25
#
#    Current and Voltage  Hydraulic Pressure  Belt Thickness  Roller Condition
# 0                14.34              376.48         1.54675            68.245
# 1                15.03              384.20         1.54650            68.172
# 2                15.43              379.79         1.54625            68.099
# 3                14.35              383.95         1.54600            68.026
# 4                15.65              383.02         1.54575            67.953
# Non-numeric columns: Index(['Status', 'Description'], dtype='object')
#             Timestamp  Vibration Frequency  Vibration Amplitude  \
# 0 2026-05-14 00:15:00              1498.37                 0.04
# 1 2026-05-14 00:30:00              1503.22                 0.06
# 2 2026-05-14 00:45:00              1508.11                 0.04
# 3 2026-05-14 01:00:00              1498.13                 0.06
# 4 2026-05-14 01:15:00              1494.89                 0.05
#
#    Bearing Temperature  Motor Temperature  Belt Load  Torque  Noise Levels  \
# 0               77.076             96.975       1.07  295.50         59.68
# 1               77.307             96.755       1.21  314.38         58.20
# 2               77.474             97.661       1.29  311.84         56.16
# 3               77.785             97.471       1.07  317.14         55.39
# 4               77.813             97.814       1.33  305.58         62.25
#
#    Current and Voltage  Hydraulic Pressure  Belt Thickness  Roller Condition
# 0                14.34              376.48         1.54675            68.245
# 1                15.03              384.20         1.54650            68.172
# 2                15.43              379.79         1.54625            68.099
# 3                14.35              383.95         1.54600            68.026
# 4                15.65              383.02         1.54575            67.953
# Non-numeric columns: Index(['Status', 'Description'], dtype='object')
#             Timestamp  Vibration Frequency  Vibration Amplitude  \
# 0 2026-05-14 00:15:00              1498.37                 0.04
# 1 2026-05-14 00:30:00              1503.22                 0.06
# 2 2026-05-14 00:45:00              1508.11                 0.04
# 3 2026-05-14 01:00:00              1498.13                 0.06
# 4 2026-05-14 01:15:00              1494.89                 0.05
#
#    Bearing Temperature  Motor Temperature  Belt Load  Torque  Noise Levels  \
# 0               77.076             96.975       1.07  295.50         59.68
# 1               77.307             96.755       1.21  314.38         58.20
# 2               77.474             97.661       1.29  311.84         56.16
# 3               77.785             97.471       1.07  317.14         55.39
# 4               77.813             97.814       1.33  305.58         62.25
#
#    Current and Voltage  Hydraulic Pressure  Belt Thickness  Roller Condition
# 0                14.34              376.48         1.54675            68.245
# 1                15.03              384.20         1.54650            68.172
# 2                15.43              379.79         1.54625            68.099
# 3                14.35              383.95         1.54600            68.026
# 4                15.65              383.02         1.54575            67.953

# %%
import joblib
import pandas as pd
import matplotlib.pyplot as plt

# Load the saved XGBoost models
clf_model = joblib.load('xgb_classifier.pkl')   # XGBoost classifier for downtime status
reg_model = joblib.load('xgb_regressor.pkl')      # XGBoost regressor for downtime timestamp

# Get the expected feature names (order must match training)
expected_features_clf = clf_model.feature_names_in_
expected_features_reg = reg_model.feature_names_in_

# Assume all_sheets is a dictionary of sheet_name: DataFrame,
# e.g., all_sheets = pd.read_excel("TestFile.xlsx", sheet_name=None)

final_predictions = []

for sheet_name, df in all_sheets.items():
    # Convert Timestamp to datetime and drop invalid rows
    df['Timestamp'] = pd.to_datetime(df['Timestamp'], errors='coerce')
    df = df.dropna(subset=['Timestamp'])
    
    # Create timestamp_numeric if missing (assume seconds since epoch)
    if 'timestamp_numeric' not in df.columns:
        df['timestamp_numeric'] = df['Timestamp'].apply(lambda x: x.timestamp())
    
    # Reindex to match training features for classifier
    X_test_clf = df.reindex(columns=expected_features_clf, fill_value=0).fillna(0)
    
    # Get predicted probabilities for downtime (class 1)
    downtime_probs = clf_model.predict_proba(X_test_clf)[:, 1]
    
    # Attach probabilities to the DataFrame
    df['downtime_prob'] = downtime_probs
    
    # Print probability distribution stats for debugging/inspection
    print(f"\n=== {sheet_name} Probability Stats ===")
    print(f"Min: {df['downtime_prob'].min()}, Max: {df['downtime_prob'].max()}, Mean: {df['downtime_prob'].mean()}")
    plt.hist(df['downtime_prob'], bins=20)
    plt.title(f'Downtime Probability Distribution - {sheet_name}')
    plt.xlabel('Probability')
    plt.ylabel('Count')
    plt.show()
    
    # Rank rows by downtime probability in descending order
    df_sorted = df.sort_values(by='downtime_prob', ascending=False)
    
    # Pick the top candidate (the row with the highest downtime probability)
    if not df_sorted.empty:
        top_candidate = df_sorted.iloc[0:1].copy()  # top 1 row as DataFrame
    else:
        top_candidate = pd.DataFrame()
    
    # If no candidate is found, prepare a placeholder row
    if top_candidate.empty:
        sheet_predictions = pd.DataFrame({
            'Sheet': [sheet_name],
            'Index': [None],
            'Downtime_Probability': [None],
            'Predicted_Downtime_Timestamp': ["No downtime predicted"]
        })
    else:
        # Prepare regressor input for the top candidate
        X_test_reg = top_candidate.reindex(columns=expected_features_reg, fill_value=0).fillna(0)
        y_pred_numeric = reg_model.predict(X_test_reg)
        predicted_datetimes = pd.to_datetime(y_pred_numeric, unit='s')
        
        sheet_predictions = pd.DataFrame({
            'Sheet': [sheet_name],
            'Index': top_candidate.index,
            'Downtime_Probability': top_candidate['downtime_prob'],
            'Predicted_Downtime_Timestamp': predicted_datetimes
        })
    
    final_predictions.append(sheet_predictions)

# Combine predictions from all sheets
if final_predictions:
    final_df = pd.concat(final_predictions, ignore_index=True)
    # Print output in the requested format for each scenario
    for sheet in final_df['Sheet'].unique():
        row = final_df[final_df['Sheet'] == sheet].iloc[0]
        print(f"Most probable downtime for {sheet} : {row['Predicted_Downtime_Timestamp']}")
    final_df.to_csv('Ranked_Downtime_Candidates.csv', index=False)
else:
    print("No predictions across any sheets.")
# Out:
# === Scenario 1 Probability Stats ===
# Min: 2.6382093665233697e-07, Max: 0.003049652324989438, Mean: 1.1232828001084272e-05
# === Scenario 2 Probability Stats ===
# Min: 2.6382093665233697e-07, Max: 0.0005748505936935544, Mean: 7.049800387903815e-06
# === Scenario 3 Probability Stats ===
# Min: 2.6382093665233697e-07, Max: 0.0005748505936935544, Mean: 5.7422589634370524e-06
# Most probable downtime for Scenario 1 : 2026-01-19 13:09:20
# Most probable downtime for Scenario 2 : 2025-11-09 06:43:12
# Most probable downtime for Scenario 3 : 2025-11-09 06:36:48
