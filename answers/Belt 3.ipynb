# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Load the dataset
file_path = 'Belt 3 Test Data.xlsx'  # Update with your actual file path if needed
all_sheets = pd.read_excel(file_path, header=None, sheet_name=None)

column_names = [
    "Name","Timestamp", "Status", "Description","Vibration Frequency","Vibration Amplitude", "Bearing Temperature", 
    "Motor Temperature", "Belt Load", "Torque", "Noise Levels", "Current and Voltage", 
    "Hydraulic Pressure","Belt Thickness", "Roller Condition" 
    
]
for sheet_name, df in all_sheets.items():
    df.columns = column_names
    
    print("First 5 rows:")
    print(df.head())
    print("\nData Info:")
    print(df.info())
    print("\nSummary Statistics:")
    print(df.describe())

    # Step 3: Check for missing values
    missing = df.isnull().sum()
    print("\nMissing Values per Column:")
    print(missing)

    # Visualize missing values
    missing.plot(kind='bar', title='Missing Values per Column')
    plt.xlabel('Columns')
    plt.ylabel('Number of Missing Values')
    plt.show()

    # Step 2: Quick overview of the data
# Out:
# First 5 rows:
#               Name           Timestamp   Status Description  \
# 0  Conveyor Belt 4 2026-05-14 00:15:00  Running         NaN
# 1  Conveyor Belt 4 2026-05-14 00:30:00  Running         NaN
# 2  Conveyor Belt 4 2026-05-14 00:45:00  Running         NaN
# 3  Conveyor Belt 4 2026-05-14 01:00:00  Running         NaN
# 4  Conveyor Belt 4 2026-05-14 01:15:00  Running         NaN
#
#    Vibration Frequency  Vibration Amplitude  Bearing Temperature  \
# 0              1498.37                 0.04               77.076
# 1              1503.22                 0.06               77.307
# 2              1508.11                 0.04               77.474
# 3              1498.13                 0.06               77.785
# 4              1494.89                 0.05               77.813
#
#    Motor Temperature  Belt Load  Torque  Noise Levels  Current and Voltage  \
# 0             96.975       1.07  295.50         59.68                14.34
# 1             96.755       1.21  314.38         58.20                15.03
# 2             97.661       1.29  311.84         56.16                15.43
# 3             97.471       1.07  317.14         55.39                14.35
# 4             97.814       1.33  305.58         62.25                15.65
#
#    Hydraulic Pressure  Belt Thickness  Roller Condition
# 0              376.48         1.54675            68.245
# 1              384.20         1.54650            68.172
# 2              379.79         1.54625            68.099
# 3              383.95         1.54600            68.026
# 4              383.02         1.54575            67.953
#
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1276 entries, 0 to 1275
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 1276 non-null   object
#  1   Timestamp            1276 non-null   datetime64[ns]
#  2   Status               1276 non-null   object
#  3   Description          98 non-null     object
#  4   Vibration Frequency  1276 non-null   float64
#  5   Vibration Amplitude  1276 non-null   float64
#  6   Bearing Temperature  1276 non-null   float64
#  7   Motor Temperature    1276 non-null   float64
#  8   Belt Load            1276 non-null   float64
#  9   Torque               1276 non-null   float64
#  10  Noise Levels         1276 non-null   float64
#  11  Current and Voltage  1276 non-null   float64
#  12  Hydraulic Pressure   1276 non-null   float64
#  13  Belt Thickness       1276 non-null   float64
#  14  Roller Condition     1276 non-null   float64
# dtypes: datetime64[ns](1), float64(11), object(3)
# memory usage: 149.7+ KB
# None
#
# Summary Statistics:
#        Vibration Frequency  Vibration Amplitude  Bearing Temperature  \
# count          1276.000000          1276.000000          1276.000000
# mean           1498.780948             0.049451            68.965490
# std              11.855199             0.007691             5.903165
# min            1463.390000             0.040000            60.000000
# 25%            1491.340000             0.040000            64.012000
# 50%            1498.660000             0.050000            68.584000
# 75%            1505.600000             0.060000            74.230000
# max            1537.170000             0.060000            78.848000
#
#        Motor Temperature    Belt Load       Torque  Noise Levels  \
# count        1276.000000  1276.000000  1276.000000   1276.000000
# mean           88.308879     1.193190   299.724138     59.897108
# std            11.723232     0.117004    12.558510      3.124208
# min            54.930000     1.000000   280.000000     55.000000
# 25%            80.610000     1.100000   287.370000     57.810000
# 50%            87.930000     1.180000   299.840000     59.680000
# 75%            95.610000     1.290000   311.392500     62.740000
# max           126.020000     1.400000   319.710000     65.000000
#
#        Current and Voltage  Hydraulic Pressure  Belt Thickness  \
# count          1276.000000         1276.000000     1276.000000
# mean             14.962853          379.937531        1.613127
# std               0.586882            3.196349        0.055502
# min              14.000000          375.000000        1.522000
# 25%              14.480000          377.180000        1.561750
# 50%              14.910000          379.920000        1.616375
# 75%              15.460000          383.190000        1.663500
# max              16.000000          384.930000        1.700000
#
#        Roller Condition
# count       1276.000000
# mean          85.239183
# std            9.172732
# min           67.515000
# 25%           78.227750
# 50%           85.984000
# 75%           93.211000
# max          100.000000
#
# Missing Values per Column:
# Name                      0
# Timestamp                 0
# Status                    0
# Description            1178
# Vibration Frequency       0
# Vibration Amplitude       0
# Bearing Temperature       0
# Motor Temperature         0
# Belt Load                 0
# Torque                    0
# Noise Levels              0
# Current and Voltage       0
# Hydraulic Pressure        0
# Belt Thickness            0
# Roller Condition          0
# dtype: int64
# First 5 rows:
#               Name           Timestamp   Status Description  \
# 0  Conveyor Belt 4 2026-05-14 00:15:00  Running         NaN
# 1  Conveyor Belt 4 2026-05-14 00:30:00  Running         NaN
# 2  Conveyor Belt 4 2026-05-14 00:45:00  Running         NaN
# 3  Conveyor Belt 4 2026-05-14 01:00:00  Running         NaN
# 4  Conveyor Belt 4 2026-05-14 01:15:00  Running         NaN
#
#    Vibration Frequency  Vibration Amplitude  Bearing Temperature  \
# 0              1498.37                 0.04               77.076
# 1              1503.22                 0.06               77.307
# 2              1508.11                 0.04               77.474
# 3              1498.13                 0.06               77.785
# 4              1494.89                 0.05               77.813
#
#    Motor Temperature  Belt Load  Torque  Noise Levels  Current and Voltage  \
# 0             96.975       1.07  295.50         59.68                14.34
# 1             96.755       1.21  314.38         58.20                15.03
# 2             97.661       1.29  311.84         56.16                15.43
# 3             97.471       1.07  317.14         55.39                14.35
# 4             97.814       1.33  305.58         62.25                15.65
#
#    Hydraulic Pressure  Belt Thickness  Roller Condition
# 0              376.48         1.54675            68.245
# 1              384.20         1.54650            68.172
# 2              379.79         1.54625            68.099
# 3              383.95         1.54600            68.026
# 4              383.02         1.54575            67.953
#
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 716 entries, 0 to 715
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 716 non-null    object
#  1   Timestamp            716 non-null    datetime64[ns]
#  2   Status               716 non-null    object
#  3   Description          56 non-null     object
#  4   Vibration Frequency  716 non-null    float64
#  5   Vibration Amplitude  716 non-null    float64
#  6   Bearing Temperature  716 non-null    float64
#  7   Motor Temperature    716 non-null    float64
#  8   Belt Load            716 non-null    float64
#  9   Torque               716 non-null    float64
#  10  Noise Levels         716 non-null    float64
#  11  Current and Voltage  716 non-null    float64
#  12  Hydraulic Pressure   716 non-null    float64
#  13  Belt Thickness       716 non-null    float64
#  14  Roller Condition     716 non-null    float64
# dtypes: datetime64[ns](1), float64(11), object(3)
# memory usage: 84.0+ KB
# None
#
# Summary Statistics:
#        Vibration Frequency  Vibration Amplitude  Bearing Temperature  \
# count           716.000000           716.000000           716.000000
# mean           1499.100628             0.049972            68.832249
# std               5.593945             0.008881             5.942009
# min            1490.000000             0.040000            60.000000
# 25%            1494.400000             0.040000            63.926000
# 50%            1499.080000             0.050000            68.576000
# 75%            1503.540000             0.060000            74.191750
# max            1509.660000             0.080000            78.848000
#
#        Motor Temperature   Belt Load      Torque  Noise Levels  \
# count         716.000000  716.000000  716.000000    716.000000
# mean           88.479047    1.195084  299.599106     59.896662
# std             5.960862    0.134714   12.553840      3.128875
# min            80.000000    0.830000  280.000000     55.000000
# 25%            83.116000    1.080000  287.370000     57.810000
# 50%            88.167000    1.190000  299.840000     59.680000
# 75%            93.338500    1.300000  311.370000     62.740000
# max            99.410000    1.680000  319.710000     65.000000
#
#        Current and Voltage  Hydraulic Pressure  Belt Thickness  \
# count           716.000000          716.000000      716.000000
# mean             14.961746          379.945293        1.615931
# std               0.588183            3.195858        0.050751
# min              14.000000          375.000000        1.522000
# 25%              14.480000          377.255000        1.576187
# 50%              14.910000          379.920000        1.617375
# 75%              15.460000          383.190000        1.658562
# max              16.000000          384.930000        1.700000
#
#        Roller Condition
# count        716.000000
# mean          86.431380
# std            9.321158
# min           67.515000
# 25%           79.249750
# 50%           87.918500
# 75%           93.941000
# max          100.000000
#
# Missing Values per Column:
# Name                     0
# Timestamp                0
# Status                   0
# Description            660
# Vibration Frequency      0
# Vibration Amplitude      0
# Bearing Temperature      0
# Motor Temperature        0
# Belt Load                0
# Torque                   0
# Noise Levels             0
# Current and Voltage      0
# Hydraulic Pressure       0
# Belt Thickness           0
# Roller Condition         0
# dtype: int64
# First 5 rows:
#               Name           Timestamp   Status Description  \
# 0  Conveyor Belt 4 2026-05-14 00:15:00  Running         NaN
# 1  Conveyor Belt 4 2026-05-14 00:30:00  Running         NaN
# 2  Conveyor Belt 4 2026-05-14 00:45:00  Running         NaN
# 3  Conveyor Belt 4 2026-05-14 01:00:00  Running         NaN
# 4  Conveyor Belt 4 2026-05-14 01:15:00  Running         NaN
#
#    Vibration Frequency  Vibration Amplitude  Bearing Temperature  \
# 0              1498.37                 0.04               77.076
# 1              1503.22                 0.06               77.307
# 2              1508.11                 0.04               77.474
# 3              1498.13                 0.06               77.785
# 4              1494.89                 0.05               77.813
#
#    Motor Temperature  Belt Load  Torque  Noise Levels  Current and Voltage  \
# 0             96.975       1.07  295.50         59.68                14.34
# 1             96.755       1.21  314.38         58.20                15.03
# 2             97.661       1.29  311.84         56.16                15.43
# 3             97.471       1.07  317.14         55.39                14.35
# 4             97.814       1.33  305.58         62.25                15.65
#
#    Hydraulic Pressure  Belt Thickness  Roller Condition
# 0              376.48         1.54675            68.245
# 1              384.20         1.54650            68.172
# 2              379.79         1.54625            68.099
# 3              383.95         1.54600            68.026
# 4              383.02         1.54575            67.953
#
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2488 entries, 0 to 2487
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 2488 non-null   object
#  1   Timestamp            2488 non-null   datetime64[ns]
#  2   Status               2488 non-null   object
#  3   Description          182 non-null    object
#  4   Vibration Frequency  2488 non-null   float64
#  5   Vibration Amplitude  2488 non-null   float64
#  6   Bearing Temperature  2488 non-null   float64
#  7   Motor Temperature    2488 non-null   float64
#  8   Belt Load            2488 non-null   float64
#  9   Torque               2488 non-null   float64
#  10  Noise Levels         2488 non-null   float64
#  11  Current and Voltage  2488 non-null   float64
#  12  Hydraulic Pressure   2488 non-null   float64
#  13  Belt Thickness       2488 non-null   float64
#  14  Roller Condition     2488 non-null   float64
# dtypes: datetime64[ns](1), float64(11), object(3)
# memory usage: 291.7+ KB
# None
#
# Summary Statistics:
#        Vibration Frequency  Vibration Amplitude  Bearing Temperature  \
# count          2488.000000          2488.000000          2488.000000
# mean           1499.122657             0.049490            69.027269
# std               5.558111             0.007695             7.392879
# min            1490.000000             0.040000            33.920000
# 25%            1494.400000             0.040000            63.926000
# 50%            1499.080000             0.050000            68.584000
# 75%            1503.540000             0.060000            74.330000
# max            1509.660000             0.060000           104.640000
#
#        Motor Temperature    Belt Load       Torque  Noise Levels  \
# count        2488.000000  2488.000000  2488.000000   2488.000000
# mean           88.618476     1.193867   299.762862     59.972508
# std             5.837342     0.116625    12.516821      4.552097
# min            80.000000     1.000000   280.000000     39.220000
# 25%            83.138000     1.100000   287.370000     56.890000
# 50%            88.478000     1.180000   299.840000     59.680000
# 75%            93.289000     1.290000   311.370000     62.820000
# max            99.410000     1.400000   319.710000     81.360000
#
#        Current and Voltage  Hydraulic Pressure  Belt Thickness  \
# count          2488.000000         2488.000000     2488.000000
# mean             14.966218          379.948304        1.617081
# std               0.585035            3.182597        0.054140
# min              14.000000          375.000000        1.522000
# 25%              14.480000          377.280000        1.566500
# 50%              14.910000          379.920000        1.626250
# 75%              15.460000          383.160000        1.664500
# max              16.000000          384.930000        1.700000
#
#        Roller Condition
# count       2488.000000
# mean          84.312922
# std            9.602845
# min           67.515000
# 25%           75.910000
# 50%           84.451000
# 75%           93.010250
# max          100.000000
#
# Missing Values per Column:
# Name                      0
# Timestamp                 0
# Status                    0
# Description            2306
# Vibration Frequency       0
# Vibration Amplitude       0
# Bearing Temperature       0
# Motor Temperature         0
# Belt Load                 0
# Torque                    0
# Noise Levels              0
# Current and Voltage       0
# Hydraulic Pressure        0
# Belt Thickness            0
# Roller Condition          0
# dtype: int64

# %%
for sheet_name, df in all_sheets.items():
    if df['Name'].nunique() == 1:
        print("The 'name' column is constant and will be dropped.")
        df.drop('Name', axis=1, inplace=True)
# Out:
# The 'name' column is constant and will be dropped.
# The 'name' column is constant and will be dropped.
# The 'name' column is constant and will be dropped.

# %%
import pandas as pd

for sheet_name, df in all_sheets.items():
    # Convert 'Timestamp' column to datetime, coercing errors into NaT
    df['Timestamp'] = pd.to_datetime(df['Timestamp'], errors='coerce')

    # Check for any invalid dates that were converted to NaT
    invalid_dates = df[df['Timestamp'].isnull()]
    print("Invalid dates found:\n", invalid_dates)

    # Optionally, drop rows with invalid dates
    df = df.dropna(subset=['Timestamp'])

    # Extract components if needed
    df['year'] = df['Timestamp'].dt.year
    df['month'] = df['Timestamp'].dt.month
    df['day'] = df['Timestamp'].dt.day
    df['hour'] = df['Timestamp'].dt.hour
    df['minute'] = df['Timestamp'].dt.minute
    df['second'] = df['Timestamp'].dt.second

    # Convert to a numeric timestamp if required
    df['timestamp_numeric'] = df['Timestamp'].apply(lambda x: x.timestamp())

    print(df.info())
# Out:
# Invalid dates found:
#  Empty DataFrame
# Columns: [Timestamp, Status, Description, Vibration Frequency, Vibration Amplitude, Bearing Temperature, Motor Temperature, Belt Load, Torque, Noise Levels, Current and Voltage, Hydraulic Pressure, Belt Thickness, Roller Condition]
# Index: []
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1276 entries, 0 to 1275
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Timestamp            1276 non-null   datetime64[ns]
#  1   Status               1276 non-null   object
#  2   Description          98 non-null     object
#  3   Vibration Frequency  1276 non-null   float64
#  4   Vibration Amplitude  1276 non-null   float64
#  5   Bearing Temperature  1276 non-null   float64
#  6   Motor Temperature    1276 non-null   float64
#  7   Belt Load            1276 non-null   float64
#  8   Torque               1276 non-null   float64
#  9   Noise Levels         1276 non-null   float64
#  10  Current and Voltage  1276 non-null   float64
#  11  Hydraulic Pressure   1276 non-null   float64
#  12  Belt Thickness       1276 non-null   float64
#  13  Roller Condition     1276 non-null   float64
#  14  year                 1276 non-null   int64
#  15  month                1276 non-null   int64
#  16  day                  1276 non-null   int64
#  17  hour                 1276 non-null   int64
#  18  minute               1276 non-null   int64
#  19  second               1276 non-null   int64
#  20  timestamp_numeric    1276 non-null   float64
# dtypes: datetime64[ns](1), float64(12), int64(6), object(2)
# memory usage: 219.3+ KB
# None
# Invalid dates found:
#  Empty DataFrame
# Columns: [Timestamp, Status, Description, Vibration Frequency, Vibration Amplitude, Bearing Temperature, Motor Temperature, Belt Load, Torque, Noise Levels, Current and Voltage, Hydraulic Pressure, Belt Thickness, Roller Condition]
# Index: []
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 716 entries, 0 to 715
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Timestamp            716 non-null    datetime64[ns]
#  1   Status               716 non-null    object
#  2   Description          56 non-null     object
#  3   Vibration Frequency  716 non-null    float64
#  4   Vibration Amplitude  716 non-null    float64
#  5   Bearing Temperature  716 non-null    float64
#  6   Motor Temperature    716 non-null    float64
#  7   Belt Load            716 non-null    float64
#  8   Torque               716 non-null    float64
#  9   Noise Levels         716 non-null    float64
#  10  Current and Voltage  716 non-null    float64
#  11  Hydraulic Pressure   716 non-null    float64
#  12  Belt Thickness       716 non-null    float64
#  13  Roller Condition     716 non-null    float64
#  14  year                 716 non-null    int64
#  15  month                716 non-null    int64
#  16  day                  716 non-null    int64
#  17  hour                 716 non-null    int64
#  18  minute               716 non-null    int64
#  19  second               716 non-null    int64
#  20  timestamp_numeric    716 non-null    float64
# dtypes: datetime64[ns](1), float64(12), int64(6), object(2)
# memory usage: 123.1+ KB
# None
# Invalid dates found:
#  Empty DataFrame
# Columns: [Timestamp, Status, Description, Vibration Frequency, Vibration Amplitude, Bearing Temperature, Motor Temperature, Belt Load, Torque, Noise Levels, Current and Voltage, Hydraulic Pressure, Belt Thickness, Roller Condition]
# Index: []
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2488 entries, 0 to 2487
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Timestamp            2488 non-null   datetime64[ns]
#  1   Status               2488 non-null   object
#  2   Description          182 non-null    object
#  3   Vibration Frequency  2488 non-null   float64
#  4   Vibration Amplitude  2488 non-null   float64
#  5   Bearing Temperature  2488 non-null   float64
#  6   Motor Temperature    2488 non-null   float64
#  7   Belt Load            2488 non-null   float64
#  8   Torque               2488 non-null   float64
#  9   Noise Levels         2488 non-null   float64
#  10  Current and Voltage  2488 non-null   float64
#  11  Hydraulic Pressure   2488 non-null   float64
#  12  Belt Thickness       2488 non-null   float64
#  13  Roller Condition     2488 non-null   float64
#  14  year                 2488 non-null   int64
#  15  month                2488 non-null   int64
#  16  day                  2488 non-null   int64
#  17  hour                 2488 non-null   int64
#  18  minute               2488 non-null   int64
#  19  second               2488 non-null   int64
#  20  timestamp_numeric    2488 non-null   float64
# dtypes: datetime64[ns](1), float64(12), int64(6), object(2)
# memory usage: 427.6+ KB
# None

# %%
for sheet_name, df in all_sheets.items():
    nat_count = df['Timestamp'].isna().sum()
    print("Number of NaT values in 'Timestamp':", nat_count)
    df.head()
# Out:
# Number of NaT values in 'Timestamp': 0
# Number of NaT values in 'Timestamp': 0
# Number of NaT values in 'Timestamp': 0

# %%
for sheet_name, df in all_sheets.items():
    # One-Hot Encode the Status column
    df = pd.get_dummies(df, columns=['Status'], prefix='status')
    print(df.head())
# Out:
#             Timestamp Description  Vibration Frequency  Vibration Amplitude  \
# 0 2026-05-14 00:15:00         NaN              1498.37                 0.04
# 1 2026-05-14 00:30:00         NaN              1503.22                 0.06
# 2 2026-05-14 00:45:00         NaN              1508.11                 0.04
# 3 2026-05-14 01:00:00         NaN              1498.13                 0.06
# 4 2026-05-14 01:15:00         NaN              1494.89                 0.05
#
#    Bearing Temperature  Motor Temperature  Belt Load  Torque  Noise Levels  \
# 0               77.076             96.975       1.07  295.50         59.68
# 1               77.307             96.755       1.21  314.38         58.20
# 2               77.474             97.661       1.29  311.84         56.16
# 3               77.785             97.471       1.07  317.14         55.39
# 4               77.813             97.814       1.33  305.58         62.25
#
#    Current and Voltage  Hydraulic Pressure  Belt Thickness  Roller Condition  \
# 0                14.34              376.48         1.54675            68.245
# 1                15.03              384.20         1.54650            68.172
# 2                15.43              379.79         1.54625            68.099
# 3                14.35              383.95         1.54600            68.026
# 4                15.65              383.02         1.54575            67.953
#
#    status_Maintenance  status_Running
# 0                   0               1
# 1                   0               1
# 2                   0               1
# 3                   0               1
# 4                   0               1
#             Timestamp Description  Vibration Frequency  Vibration Amplitude  \
# 0 2026-05-14 00:15:00         NaN              1498.37                 0.04
# 1 2026-05-14 00:30:00         NaN              1503.22                 0.06
# 2 2026-05-14 00:45:00         NaN              1508.11                 0.04
# 3 2026-05-14 01:00:00         NaN              1498.13                 0.06
# 4 2026-05-14 01:15:00         NaN              1494.89                 0.05
#
#    Bearing Temperature  Motor Temperature  Belt Load  Torque  Noise Levels  \
# 0               77.076             96.975       1.07  295.50         59.68
# 1               77.307             96.755       1.21  314.38         58.20
# 2               77.474             97.661       1.29  311.84         56.16
# 3               77.785             97.471       1.07  317.14         55.39
# 4               77.813             97.814       1.33  305.58         62.25
#
#    Current and Voltage  Hydraulic Pressure  Belt Thickness  Roller Condition  \
# 0                14.34              376.48         1.54675            68.245
# 1                15.03              384.20         1.54650            68.172
# 2                15.43              379.79         1.54625            68.099
# 3                14.35              383.95         1.54600            68.026
# 4                15.65              383.02         1.54575            67.953
#
#    status_Maintenance  status_Running
# 0                   0               1
# 1                   0               1
# 2                   0               1
# 3                   0               1
# 4                   0               1
#             Timestamp Description  Vibration Frequency  Vibration Amplitude  \
# 0 2026-05-14 00:15:00         NaN              1498.37                 0.04
# 1 2026-05-14 00:30:00         NaN              1503.22                 0.06
# 2 2026-05-14 00:45:00         NaN              1508.11                 0.04
# 3 2026-05-14 01:00:00         NaN              1498.13                 0.06
# 4 2026-05-14 01:15:00         NaN              1494.89                 0.05
#
#    Bearing Temperature  Motor Temperature  Belt Load  Torque  Noise Levels  \
# 0               77.076             96.975       1.07  295.50         59.68
# 1               77.307             96.755       1.21  314.38         58.20
# 2               77.474             97.661       1.29  311.84         56.16
# 3               77.785             97.471       1.07  317.14         55.39
# 4               77.813             97.814       1.33  305.58         62.25
#
#    Current and Voltage  Hydraulic Pressure  Belt Thickness  Roller Condition  \
# 0                14.34              376.48         1.54675            68.245
# 1                15.03              384.20         1.54650            68.172
# 2                15.43              379.79         1.54625            68.099
# 3                14.35              383.95         1.54600            68.026
# 4                15.65              383.02         1.54575            67.953
#
#    status_Maintenance  status_Running
# 0                   0               1
# 1                   0               1
# 2                   0               1
# 3                   0               1
# 4                   0               1

# %%
mydf=""
for sheet_name, df in all_sheets.items():
    # Identify non-numeric columns
    non_numeric_cols = df.select_dtypes(include=['object']).columns
    print("Non-numeric columns:", non_numeric_cols)

    # Drop non-numeric columns that are not needed for the model
    df_model = df.drop(non_numeric_cols, axis=1)
    df=df_model
    print(df.head())
# Out:
# Non-numeric columns: Index(['Status', 'Description'], dtype='object')
#             Timestamp  Vibration Frequency  Vibration Amplitude  \
# 0 2026-05-14 00:15:00              1498.37                 0.04
# 1 2026-05-14 00:30:00              1503.22                 0.06
# 2 2026-05-14 00:45:00              1508.11                 0.04
# 3 2026-05-14 01:00:00              1498.13                 0.06
# 4 2026-05-14 01:15:00              1494.89                 0.05
#
#    Bearing Temperature  Motor Temperature  Belt Load  Torque  Noise Levels  \
# 0               77.076             96.975       1.07  295.50         59.68
# 1               77.307             96.755       1.21  314.38         58.20
# 2               77.474             97.661       1.29  311.84         56.16
# 3               77.785             97.471       1.07  317.14         55.39
# 4               77.813             97.814       1.33  305.58         62.25
#
#    Current and Voltage  Hydraulic Pressure  Belt Thickness  Roller Condition
# 0                14.34              376.48         1.54675            68.245
# 1                15.03              384.20         1.54650            68.172
# 2                15.43              379.79         1.54625            68.099
# 3                14.35              383.95         1.54600            68.026
# 4                15.65              383.02         1.54575            67.953
# Non-numeric columns: Index(['Status', 'Description'], dtype='object')
#             Timestamp  Vibration Frequency  Vibration Amplitude  \
# 0 2026-05-14 00:15:00              1498.37                 0.04
# 1 2026-05-14 00:30:00              1503.22                 0.06
# 2 2026-05-14 00:45:00              1508.11                 0.04
# 3 2026-05-14 01:00:00              1498.13                 0.06
# 4 2026-05-14 01:15:00              1494.89                 0.05
#
#    Bearing Temperature  Motor Temperature  Belt Load  Torque  Noise Levels  \
# 0               77.076             96.975       1.07  295.50         59.68
# 1               77.307             96.755       1.21  314.38         58.20
# 2               77.474             97.661       1.29  311.84         56.16
# 3               77.785             97.471       1.07  317.14         55.39
# 4               77.813             97.814       1.33  305.58         62.25
#
#    Current and Voltage  Hydraulic Pressure  Belt Thickness  Roller Condition
# 0                14.34              376.48         1.54675            68.245
# 1                15.03              384.20         1.54650            68.172
# 2                15.43              379.79         1.54625            68.099
# 3                14.35              383.95         1.54600            68.026
# 4                15.65              383.02         1.54575            67.953
# Non-numeric columns: Index(['Status', 'Description'], dtype='object')
#             Timestamp  Vibration Frequency  Vibration Amplitude  \
# 0 2026-05-14 00:15:00              1498.37                 0.04
# 1 2026-05-14 00:30:00              1503.22                 0.06
# 2 2026-05-14 00:45:00              1508.11                 0.04
# 3 2026-05-14 01:00:00              1498.13                 0.06
# 4 2026-05-14 01:15:00              1494.89                 0.05
#
#    Bearing Temperature  Motor Temperature  Belt Load  Torque  Noise Levels  \
# 0               77.076             96.975       1.07  295.50         59.68
# 1               77.307             96.755       1.21  314.38         58.20
# 2               77.474             97.661       1.29  311.84         56.16
# 3               77.785             97.471       1.07  317.14         55.39
# 4               77.813             97.814       1.33  305.58         62.25
#
#    Current and Voltage  Hydraulic Pressure  Belt Thickness  Roller Condition
# 0                14.34              376.48         1.54675            68.245
# 1                15.03              384.20         1.54650            68.172
# 2                15.43              379.79         1.54625            68.099
# 3                14.35              383.95         1.54600            68.026
# 4                15.65              383.02         1.54575            67.953

# %%
import joblib
import pandas as pd
import matplotlib.pyplot as plt

# Load the saved XGBoost models
clf_model = joblib.load('xgb_classifier.pkl')   # XGBoost classifier for downtime status
reg_model = joblib.load('xgb_regressor.pkl')      # XGBoost regressor for downtime timestamp

# Get the expected feature names (order must match training)
expected_features_clf = clf_model.feature_names_in_
expected_features_reg = reg_model.feature_names_in_

# Assume all_sheets is a dictionary of sheet_name: DataFrame,
# e.g., all_sheets = pd.read_excel("TestFile.xlsx", sheet_name=None)

final_predictions = []

for sheet_name, df in all_sheets.items():
    # Convert Timestamp to datetime and drop invalid rows
    df['Timestamp'] = pd.to_datetime(df['Timestamp'], errors='coerce')
    df = df.dropna(subset=['Timestamp'])
    
    # Create timestamp_numeric if missing (assume seconds since epoch)
    if 'timestamp_numeric' not in df.columns:
        df['timestamp_numeric'] = df['Timestamp'].apply(lambda x: x.timestamp())
    
    # Reindex to match training features for classifier
    X_test_clf = df.reindex(columns=expected_features_clf, fill_value=0).fillna(0)
    
    # Get predicted probabilities for downtime (class 1)
    downtime_probs = clf_model.predict_proba(X_test_clf)[:, 1]
    
    # Attach probabilities to the DataFrame
    df['downtime_prob'] = downtime_probs
    
    # Print probability distribution stats for debugging/inspection
    print(f"\n=== {sheet_name} Probability Stats ===")
    print(f"Min: {df['downtime_prob'].min()}, Max: {df['downtime_prob'].max()}, Mean: {df['downtime_prob'].mean()}")
    plt.hist(df['downtime_prob'], bins=20)
    plt.title(f'Downtime Probability Distribution - {sheet_name}')
    plt.xlabel('Probability')
    plt.ylabel('Count')
    plt.show()
    
    # Rank rows by downtime probability in descending order
    df_sorted = df.sort_values(by='downtime_prob', ascending=False)
    
    # Pick the top candidate (the row with the highest downtime probability)
    if not df_sorted.empty:
        top_candidate = df_sorted.iloc[0:1].copy()  # top 1 row as DataFrame
    else:
        top_candidate = pd.DataFrame()
    
    # If no candidate is found, prepare a placeholder row
    if top_candidate.empty:
        sheet_predictions = pd.DataFrame({
            'Sheet': [sheet_name],
            'Index': [None],
            'Downtime_Probability': [None],
            'Predicted_Downtime_Timestamp': ["No downtime predicted"]
        })
    else:
        # Prepare regressor input for the top candidate
        X_test_reg = top_candidate.reindex(columns=expected_features_reg, fill_value=0).fillna(0)
        y_pred_numeric = reg_model.predict(X_test_reg)
        predicted_datetimes = pd.to_datetime(y_pred_numeric, unit='s')
        
        sheet_predictions = pd.DataFrame({
            'Sheet': [sheet_name],
            'Index': top_candidate.index,
            'Downtime_Probability': top_candidate['downtime_prob'],
            'Predicted_Downtime_Timestamp': predicted_datetimes
        })
    
    final_predictions.append(sheet_predictions)

# Combine predictions from all sheets
if final_predictions:
    final_df = pd.concat(final_predictions, ignore_index=True)
    # Print output in the requested format for each scenario
    for sheet in final_df['Sheet'].unique():
        row = final_df[final_df['Sheet'] == sheet].iloc[0]
        print(f"Most probable downtime for {sheet} : {row['Predicted_Downtime_Timestamp']}")
    final_df.to_csv('Ranked_Downtime_Candidates.csv', index=False)
else:
    print("No predictions across any sheets.")
# Out:
# === Scenario 1 Probability Stats ===
# Min: 2.6382093665233697e-07, Max: 0.0005748505936935544, Mean: 1.6109159332700074e-05
# === Scenario 2 Probability Stats ===
# Min: 5.950836339252419e-07, Max: 0.0005748505936935544, Mean: 6.146618943603244e-06
# === Scenario 3 Probability Stats ===
# Min: 2.6382093665233697e-07, Max: 0.0007426968077197671, Mean: 6.4537316575297154e-06
# Most probable downtime for Scenario 1 : 2025-09-28 06:56:00
# Most probable downtime for Scenario 2 : 2025-11-09 06:36:48
# Most probable downtime for Scenario 3 : 2025-11-09 06:36:48
